# %%
import time
from datetime import datetime

def log(stage, message):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] [Stage {stage}] {message}")
    time.sleep(1)  # simulate time between stages

# === Step 1: Threat modeling ===
log(1, "Threat model created: Identified possible physical and network attacks.")

# === Step 2: Secure boot initialization ===
log(2, "Secure boot verified: Firmware signature validated successfully.")

# === Step 3: Secure key injection ===
log(3, "Keys injected securely: AES-128 and RSA keys stored in secure element.")

# === Step 4: OTA firmware update check ===
log(4, "OTA update verified: New firmware integrity confirmed, update applied.")

# === Step 5: Secure decommissioning ===
log(5, "Device decommissioned: All keys deleted and device reset to factory mode.")
# Out:
# [15:50:05] [Stage 1] Threat model created: Identified possible physical and network attacks.
# [15:50:06] [Stage 2] Secure boot verified: Firmware signature validated successfully.
# [15:50:07] [Stage 3] Keys injected securely: AES-128 and RSA keys stored in secure element.
# [15:50:08] [Stage 4] OTA update verified: New firmware integrity confirmed, update applied.
# [15:50:09] [Stage 5] Device decommissioned: All keys deleted and device reset to factory mode.
